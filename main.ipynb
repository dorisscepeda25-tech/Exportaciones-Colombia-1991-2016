# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
base=pd.read_csv(r"/content/drive/MyDrive/Proyecto Herramientas de Programación/commodity_trade_statistics_data.csv")
# Out:
# /tmp/ipython-input-730429851.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   base=pd.read_csv(r"/content/drive/MyDrive/Proyecto Herramientas de Programación/commodity_trade_statistics_data.csv")

# %%
base_col=base[base["country_or_area"]=="Colombia"]

# %%
pip install ydata-profiling
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.3/399.3 kB 10.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 10.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 15.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 2.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
# ...

# %%
from ydata_profiling import ProfileReport
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>

# %%
profile = ProfileReport(base_col, title="Profiling Report")
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;meta charset=utf-8&gt;&lt;meta content=&quot;width=device-width,initial-scale=1,shrink-to-fit=no&quot; name=viewport&gt;&lt;meta content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot; name=description&gt;&lt;meta content=&quot;YData and the open source community.&quot; name=author&gt;&lt;meta content=&quot;YData Profiling vv4.17.0&quot; name=generator&gt;&lt;meta content=https://github.com/ydataai/ydata-profiling name=url&gt;&lt;meta content=&quot;2025-11-04 17:06:56.827293&quot; name=date&gt;&lt;title&gt;Profiling Report&lt;/title&gt;&lt;style&gt;@charset &quot;UTF-8&quot;;/*!
#  * Bootstrap  v5.3.3 (https://getbootstrap.com/)
#  * Copyright 2011-2024 The Bootstrap Authors
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/main/LICENSE)
# ...

# %%
base_col[['flow','quantity']].groupby("flow").sum().sort_values("quantity")
# Out:
#                quantity
# flow
# Re-Export  7.133901e+07
# Re-Import  3.504201e+08
# Import     4.409693e+11
# Export     2.161040e+12

# %%
base_col[['flow','trade_usd','year']].groupby(["flow","year"]).sum().sort_values("trade_usd")
# Out:
#                    trade_usd
# flow      year
# Re-Import 2009     174289702
#           2010     237884103
# Re-Export 2009     336226355
# Re-Import 2003     414651612
# Re-Export 2010     656752521
# ...                      ...
# Import    2014  100586516118
# Export    2014  104610037999
#           2011  108635194306
#           2013  112437129305
#           2012  114994757964
#
# [64 rows x 1 columns]

# %%
from matplotlib import pyplot as plt
_df_2['trade_usd'].plot(kind='line', figsize=(8, 4), title='trade_usd')
plt.gca().spines[['top', 'right']].set_visible(False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1201689117.py in <cell line: 0>()
#       1 from matplotlib import pyplot as plt
# ----> 2 _df_2['trade_usd'].plot(kind='line', figsize=(8, 4), title='trade_usd')
#       3 plt.gca().spines[['top', 'right']].set_visible(False)
#
# NameError: name '_df_2' is not defined

# %%
import seaborn as sns

# %%
# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="weight_kg", y="quantity",
                hue="flow", size="trade_usd",
                palette="ch:r=-.2,d=.3_r",

                sizes=(1, 8), linewidth=0,
                data=base_col, ax=ax)
# Out:
# <Axes: xlabel='weight_kg', ylabel='quantity'>

# %%
base_col.groupby("commodity").sum()
# Out:
#                                                                                       country_or_area  \
# commodity
# ALL COMMODITIES                                     ColombiaColombiaColombiaColombiaColombiaColomb...
# Abaca fibre, processed but not spun, tow, noils...                                   ColombiaColombia
# Abaca fibre, raw                                                                     ColombiaColombia
# Abrasive powder or grain on a base of other mat...  ColombiaColombiaColombiaColombiaColombiaColomb...
# Abrasive powder, grain on paper or paperboard s...  ColombiaColombiaColombiaColombiaColombiaColomb...
# ...                                                                                               ...
# Zirconium ores and concentrates                     ColombiaColombiaColombiaColombiaColombiaColomb...
# Zirconium, articles thereof, nes                    ColombiaColombiaColombiaColombiaColombiaColomb...
# ...

# %%
base[['trade_usd','country_or_area']].groupby("country_or_area").sum().sort_values("trade_usd")
# Out:
#                              trade_usd
# country_or_area
# Tuvalu                       141694791
# Wallis and Futuna Isds       356512334
# Chad                         379822208
# Guinea-Bissau                530150307
# Montserrat                   605337560
# ...                                ...
# Japan                   37162484244900
# Germany                 58697172122513
# China                   61588304582650
# USA                     73323903319056
# EU-28                   80560794323761
#
# [209 rows x 1 columns]

# %%
import geopandas as gpd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
paises=gpd.read_file(r"/content/drive/MyDrive/Proyecto Herramientas de Programación/paises/paises")
# Out:
# /usr/local/lib/python3.12/dist-packages/pyogrio/geopandas.py:275: UserWarning: More than one layer found in 'paises': 'ne_110m_admin_0_countries' (default), 'ne_110m_admin_0_countries_lakes'. Specify layer parameter to avoid this warning.
#   result = read_func(

# %%
paises.plot()
# Out:
# <Axes: >

# %%
base_col[["trade_usd","weight_kg"]].dropna().corr()
# Out:
#            trade_usd  weight_kg
# trade_usd   1.000000   0.588796
# weight_kg   0.588796   1.000000

# %%
base_col[["trade_usd","quantity"]].dropna().corr()
# Out:
#            trade_usd  quantity
# trade_usd   1.000000  0.570627
# quantity    0.570627  1.000000

# %%
base_col[["trade_usd","quantity"]].dropna().plot.scatter(x="trade_usd",y="quantity")
# Out:
# <Axes: xlabel='trade_usd', ylabel='quantity'>

# %%
base_col[["trade_usd","weight_kg"]].dropna().plot.scatter(x="trade_usd",y="weight_kg")
# Out:
# <Axes: xlabel='trade_usd', ylabel='weight_kg'>

# %%
import statsmodels.api as sm

# %%
df = pd.read_csv("ruta/dataset.csv")
df_col = df[df["country_or_area"] == "Colombia"]
df_col["year"].min(1988), df_col["year"].max(2020)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1669456336.py in <cell line: 0>()
# ----> 1 df = pd.read_csv("ruta/dataset.csv")
#       2 df_col = df[df["country_or_area"] == "Colombia"]
#       3 df_col["year"].min(1988), df_col["year"].max(2020)
#
# ...
